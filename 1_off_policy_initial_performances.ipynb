# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
perf = np.load("data/off_policy_performances.npy")

# %%
perf = perf[[0, 1, 2, 3, 4, 6, 7, 8, 9, 10, 12, 13, 14, 15, 16, 18, 19, 20, 21, 22]]

# %%
perf
# Out:
# array([0.91215008, 0.9283613 , 0.93153489, 0.93310916, 0.93371868,
#        0.46177295, 0.45618895, 0.42901418, 0.42755398, 0.44424683,
#        0.92781103, 0.93207127, 0.9335596 , 0.93419957, 0.93438852,
#        0.70746237, 0.71721673, 0.72190845, 0.72243536, 0.72338372])

# %%
# labels for plot
# r: RL dataset
# l: Linear dataset
# b (from both) RL and Linear dataset
# e: ensemble dataset
# no: it had no label but it is the same as epoch 50
labels = [            "r_10",
                      "r_20",
                      "r_30",
                      "r_40",
                      "r_50",
                      "l_10",
                      "l_20",
                      "l_30",
                      "l_40",
                      "l_50",
                      "b_10",
                      "b_20",
                      "b_30",
                      "b_40",
                      "b_50",
                      "e_10",
                      "e_20",
                      "e_30",
                      "e_40",
                      "e_50"]
fig = plt.figure(figsize=(20,5))
plt.bar(labels, perf)
# Out:
# <BarContainer object of 20 artists>

# %%
def autolabel(rects):
    """
    Attach a text label above each bar displaying its height
    """
    for rect in rects:
        height = rect.get_height()
        ax.text(rect.get_x() + rect.get_width()/2., 0.95*height,
                round(height,3),
                ha='center', va='bottom')
        
fig = plt.figure(figsize=(20,5))
ax = fig.add_subplot(1, 1, 1)
rects1 = ax.bar(labels[:5], perf[:5], label="rl")
rects2 = ax.bar(labels[5:10], perf[5:10], label="linear")
rects3 = ax.bar(labels[10:15], perf[10:15], label="linear_and_rl")
rects4 = ax.bar(labels[15:], perf[15:], label="ensemble rl")
autolabel(rects1)
autolabel(rects2)
autolabel(rects3)
autolabel(rects4)
plt.ylabel("L.E. SR")
plt.legend()
